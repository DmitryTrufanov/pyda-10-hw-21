# %% [markdown]
# # Домашнее задание к лекции "Основы веб-скрапинга и работы с API"

# %% [markdown]
# ## Задание 1.
#
# ### Обязательная часть

# %% [markdown]
# Будем парсить страницу со свежеми новостям на [habr.com/ru/all/](https://habr.com/ru/all/).
#
# Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
#
# `KEYWORDS = ['python', 'парсинг']`
#
#  Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
#
# В итоге должен формироваться датафрейм со столбцами: <дата> - <заголовок> - <ссылка>.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# очень часто сайты могут ограничивать частые запросы к себе,поэтому нужно задерживать исполнение
import time

# %%
KEYWORDS = ['erp-системы', 'удалённая работа', 'информационная безопасность']

# %%
URL = 'https://habr.com/ru/all'
req = requests.get(URL)
#req.text

# %%
soup = BeautifulSoup(req.text, 'html.parser')
#soup

# %%
# извлекаем посты
posts = soup.find_all('article', class_='post')
posts
# Out:
# [<article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/Seleditor/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/f21/4b9/a3d/f214b9a3df13c490cbb6110700b95965.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">Seleditor</span>
#  </a>
#  <span class="post__time">сегодня в 13:19</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/selectel/blog/513434/">Прототип Starship успешно прошел огневые испытания</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/selectel/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Selectel'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Selectel</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/futurenow/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Будущее здесь'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Будущее здесь</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/space/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Космонавтика'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Космонавтика</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/popular_science/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Научно-популярное'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Научно-популярное</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <div style="text-align:center;"><img src="https://habrastorage.org/webt/0z/8d/gx/0z8dgxeumcevinqk0zytdcvllt0.png"/></div><br/>
#  Компания SpaceX во главе с Илоном Маском уже давно работает над проектом ракеты нового поколения Starship, от которой зависит отправка людей на Марс в 2024 году. Ранее испытания прототипа ракеты сопровождались проблемами. Например, предыдущий прототип один раз прошел огневые испытания, второй раз — <a href="https://www.theverge.com/2020/5/29/21274931/spacex-starship-prototype-rocket-explosion-static-fire-test" rel="nofollow">взорвался</a>.<br/>
#  <br/>
#  На днях проводились новые огневые испытания усовершенствованного прототипа SN5, и на этот раз все прошло хорошо. Следующий этап — тестовый полет на высоту в 150 метров. В прошлом году подобный прыжок совершила упрощенная версия Starship, которая получила название Starhopper.<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/selectel/blog/513434/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_selectel,h_22014,h_21962,h_21910,f_popsci" id="infopanel_post_513434">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 4: ↑3 и ↓1">+2</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513434" data-post-type="publish_corp_ru,c_selectel,h_22014,h_21962,h_21910,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">0</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">154</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/selectel/blog/513434/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/niklep/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/b26/1d9/972/b261d997274172286f2c3d24cdc6dc98.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">niklep</span>
#  </a>
#  <span class="post__time">сегодня в 13:09</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513470/">Как мигрировать Zabbix с MySQL на PostgreSQL с минимальным downtime</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it-infrastructure/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'IT-инфраструктура'); }" rel="nofollow" title="Вы не подписаны на этот хаб">IT-инфраструктура</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/sys_admin/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Системное администрирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Системное администрирование</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <p><img alt="image" src="https://habrastorage.org/webt/r4/zp/yu/r4zpyuxj4ba9rh39-r5c1ekx1ts.jpeg"/></p><br>
#  <p>В свете того, что Zabbix с некоторых пор поддерживает TimescaleDB, а тут еще и вышел новый LTS релиз Zabbix, то наверняка многие заинтересовались, как осуществить миграцию с MySQL на PostgreSQL.</p><br>
#  <p>Несмотря на текст на картинке, вполне можно просто так взять и мигрировать Zabbix с MySQL на PostgreSQL. В интернете есть немало рецептов такой миграции, например:</p><br>
#  <p><a href="https://assets.zabbix.com/files/events/meetup_ru_20200619/MySQL2PgSQL_Alexander_Petrov_Gavrilov.pdf" rel="nofollow">Доклад с Zabbix Meetup</a><br>
#  <a href="https://www.youtube.com/watch?v=S-C5NCZJnt0" rel="nofollow">Видео с Youtube канала Dmitry Lambert</a></br></p><br/>
#  <p>Но я не нашел ни в одном из таких докладов информации, как же минимизировать downtime вашего мониторинга в случае, если полная миграция занимает несколько часов, что конечно зачастую является неприемлемым.</p><br/>
#  <p>Ниже я опишу свое решение данной проблемы и те подводные камни, которые пришлось обходить по пути.</p><br/>
#  <p>Важно упомянуть, что я до сих использую Zabbix 4.0. Возможно, в новых версиях схема БД поменялась и поэтапная миграция, описанная ниже, там невозможна.</p>
#  </br></br></br></div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513470/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_6398,h_221,f_admin" id="infopanel_post_513470">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513470" data-post-type="publish_ugc_ru,h_6398,h_221,f_admin" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">0</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">62</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513470/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/Antol/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/8bc/015/624/8bc015624e859bcec17a92769f4f4103.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">Antol</span>
#  </a>
#  <span class="post__time">сегодня в 12:38</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513466/">Null safety в Dart</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/dart/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Dart'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Dart</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/flutter/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Flutter'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Flutter</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/mobile_dev/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Разработка мобильных приложений'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Разработка мобильных приложений</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <blockquote>Привет, Хабр! Представляю вашему вниманию перевод статьи <a href="https://medium.com/dartlang/announcing-sound-null-safety-defd2216a6f3" rel="nofollow">«Announcing sound null safety»</a> автора Filip Hracek с моими комментариями:<br/>
#  <br/>
#  <i>Null safety — безопасная работа с пустыми ссылками. Далее по тексту для краткости и по причине устойчивости термина будет использоваться английское наименование null, null safety. Да и перевод «нулевая безопасность» наводит совсем на противоположные мысли.<br/>
#  sound — в данном контексте (sound null safety) можно перевести как «надежный».<br/>
#  Если есть предложения по улучшению перевода или нашли ошибки — пишите в личку, постараемся исправиться.</i></blockquote> Наступил важный этап для команды Dart с их представлением технического превью наработок по null safety. Null safety позволяет избежать целого класса ошибок, которые часто трудно обнаружить, а в качестве бонуса обеспечивает ряд улучшений производительности. На данный момент мы выпустили предварительное техническое превью и ждем от вас обратной связи.<br/>
#  <br/>
#  В этой статье мы раскроем планы команды Dart по развертыванию null safety, а также объясним, что скрывается за термином Sound null safety, и чем этот подход отличается от других языков программирования.
#      </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513466/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_17712,h_22176,h_6345,f_develop" id="infopanel_post_513466">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513466" data-post-type="publish_ugc_ru,h_17712,h_22176,h_6345,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">0</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">131</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513466/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/JustasWolf/" title="Автор публикации">
#  <span class="default-image_mini default-image_green">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">JustasWolf</span>
#  </a>
#  <span class="post__time">сегодня в 09:07</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/amperka/blog/513400/">Ракета от Амперки, часть 5: Разбор полетов, ремонт</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/amperka/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании Амперка'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании Амперка</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/DIY/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'DIY или Сделай сам'); }" rel="nofollow" title="Вы не подписаны на этот хаб">DIY или Сделай сам</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        Рад всех приветствовать!<br/>
#  <br/>
#  Очередная неделя работы над ракетой.<br/>
#  <br/>
#  <img src="https://habrastorage.org/webt/eu/ro/a5/euroa5uuuoktsttciejfbjiekww.jpeg"/><br/>
#  <br/>
#  В этом выпуске займемся выяснением причин срыва сопла, поиском вариантов решений и ремонтом.<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/amperka/blog/513400/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_amperka,h_21976,f_popsci" id="infopanel_post_513400">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 9: ↑7 и ↓2">+5</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513400" data-post-type="publish_corp_ru,c_amperka,h_21976,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">7</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,5k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/amperka/blog/513400/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">7</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/YaphetS7/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/4e5/b34/9b9/4e5b349b99dce25a3bd99d06143c00dc.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">YaphetS7</span>
#  </a>
#  <span class="post__time">сегодня в 03:53</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513444/">Deep Learning — как это работает? Часть 4</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/machine_learning/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Машинное обучение'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Машинное обучение</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/artificial_intelligence/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Искусственный интеллект'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Искусственный интеллект</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <a href="https://habr.com/ru/post/510804/">Часть 1</a><br/>
#  <a href="https://habr.com/ru/post/510816/">Часть 2</a><br/>
#  <a href="https://habr.com/ru/post/511372/">Часть 3</a><br/>
#  <br/>
#  В этой статье вы узнаете:<br/>
#  -О том, что такое <i>transfer learning</i> и как это работает<br/>
#  <br/>
#  -О том, что такое <i>semantic/instance segmentation</i> и как это работает<br/>
#  <br/>
#  -О том, что такое <i>object detection</i> и как это работает<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513444/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_19439,h_21922,f_develop,f_popsci" id="infopanel_post_513444">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter" title="Всего голосов 0: ↑0 и ↓0">0</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513444" data-post-type="publish_ugc_ru,h_19439,h_21922,f_develop,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">22</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">802</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513444/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/avecoder/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/940/9e4/fa8/9409e4fa8b2abefb87ec72703c8bcc0d.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">avecoder</span>
#  </a>
#  <span class="post__time">сегодня в 03:03</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513442/">Это нужно знать каждому программисту (или ядреный кликбейт про кодерский сленг)</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/freelance/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Фриланс'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Фриланс</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/it_immigration/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'IT-эмиграция'); }" rel="nofollow" title="Вы не подписаны на этот хаб">IT-эмиграция</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/history/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'История IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">История IT</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/learning_languages/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Изучение языков'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Изучение языков</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/itcompanies/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'IT-компании'); }" rel="nofollow" title="Вы не подписаны на этот хаб">IT-компании</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <img src="https://habrastorage.org/webt/jj/xa/cl/jjxaclypbohglvia_ngy276b_-g.jpeg"/><br/>
#  <br/>
#  YAGNI, KISS, DRY, WET, SLAP, ASAP, YOLO — что все это вообще значит?<br/>
#  <br/>
#  Аве, Кодер! Если ты когда-нибудь читал англоязычную литературу по программированию, проходил курсы на английском языке, работал с англоязычными коллегами-кодерами или просто даже переписывался с ними, ты наверняка встречал эти аббревиатуры и, когда один бородатый кодер говорил другому KISS — гарантирую, что твоя бровь хотя бы немного приподнималась.<br/>
#  <br/>
#  В этой статье мы разберем, что означают эти популярные в среде англоязычных IT-шников словечки, а точнее аббревиатурки.<br/>
#  <br/>
#  Визуалам сюда: <a href="https://youtu.be/ub0YtnSwqRA" rel="nofollow">youtu.be/ub0YtnSwqRA</a><br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513442/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_20694,h_20734,h_21906,h_22006,h_22026,f_management,f_popsci" id="infopanel_post_513442">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 21: ↑15 и ↓6">+9</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513442" data-post-type="publish_ugc_ru,h_20694,h_20734,h_21906,h_22006,h_22026,f_management,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">66</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">4,4k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513442/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">11</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/Morjus/" title="Автор публикации">
#  <span class="default-image_mini default-image_pink">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">Morjus</span>
#  </a>
#  <span class="post__time">вчера в 22:51</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513432/">Тесты на pytest с генерацией отчетов в Allure с использованием Docker и Gitlab Pages и частично selenium</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/python/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Python'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Python</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/web_testing/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Тестирование веб-сервисов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Тестирование веб-сервисов</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/build_automation/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Системы сборки'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Системы сборки</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <p>Этот текст предназначен для начинающих тестировщиков, желающих понять как делать отчеты на allure с историей тестов, также разъяснить где их хранить, чтобы в отчет мог заглянуть любой участник вашей команды.</p><br>
#  <p><img alt="Пример отчета, получающийся в allure" src="https://habrastorage.org/webt/bb/xd/ws/bbxdwsvdjcdawfrthmdipnxju8i.png"/></p><br>
#  <p>Когда я хотел добавить в gitlab автотесты в стеке python, allure, docker, то я выяснил, что толковых статей на эту тему нет. Пришлось разбираться самостоятельно и как результат проб и ошибок появилась эта статья, которая скорее является гайдом, частично затрагивающим написание тестов, но наибольший фокус именно на выстраивании инфраструктуры. Если у вас уже написаны тесты на allure, то вы сразу можете переходить к разделу настройки инфраструктуры. Отмечу, что текст НЕ затрагивает написание UI тестов, но я затрону инфраструктуру для них в отдельном блоке.</p>
#  </br></br></div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513432/#habracut">Читать дальше</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_340,h_19279,h_19816,f_develop" id="infopanel_post_513432">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑6 и ↓0">+6</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513432" data-post-type="publish_ugc_ru,h_340,h_19279,h_19816,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">32</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513432/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">2</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/iamsam/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/533/2a8/6a5/5332a86a58911a09fafcb76fcd3b75d6.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">iamsam</span>
#  </a>
#  <span class="post__time">вчера в 22:22</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513430/">SamsPcbGuide, часть 15: Волновое сопротивление микрополосковой линии, Гарольд Уилер и Эрик Богатин</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/electronics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Производство и разработка электроники'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Производство и разработка электроники</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/easyelectronics/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Электроника для начинающих'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Электроника для начинающих</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        Сейчас занимаюсь разработкой калькулятора для печатных плат и изучаю расчетные модели, которые стоят за табличными формулами. Добрался до волнового сопротивления микрополосковой линии и решил рассказать про модель Гарольда Уилера и то, как его Эрик Богатин недооценил, а оказалось, что у меня тут публикаций на тему волнового сопротивления вообще не было, поэтому сначала немного теории, а потом к восстановлению справедливости.
#      </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513430/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21484,h_22016,f_develop,f_popsci" id="infopanel_post_513430">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 6: ↑6 и ↓0">+6</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513430" data-post-type="publish_ugc_ru,h_21484,h_22016,f_develop,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">20</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">917</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513430/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">5</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/lega/" title="Автор публикации">
#  <span class="default-image_mini default-image_green">
#  <svg aria-hidden="true" class="icon-svg" height="24" role="img" version="1.1" viewbox="0 0 24 24" width="24"><path d="M21.5 24h-19c-1.379 0-2.5-1.122-2.5-2.5v-19c0-1.379 1.122-2.5 2.5-2.5h19c1.379 0 2.5 1.122 2.5 2.5v19c0 1.379-1.122 2.5-2.5 2.5zm-19-23c-.827 0-1.5.673-1.5 1.5v19c0 .827.673 1.5 1.5 1.5h19c.827 0 1.5-.673 1.5-1.5v-19c0-.827-.673-1.5-1.5-1.5h-19zM15.598 12.385zM19.438 15.417l-.002-.005v-.001c-.875-2.226-2.484-3.054-3.445-3.549l-.273-.143c.029-.497-.025-1.034-.167-1.599l-.128.032.123-.044c-.765-2.152-1.757-2.585-2.632-2.967l-.006-.003-.535-2.121c.357-.065.628-.375.628-.752.001-.423-.342-.765-.765-.765s-.766.342-.766.765c0 .358.248.657.581.74l-.825 1.654-.014-.003-.024-.003c-1.053-.033-1.842.369-2.5.947-.633-.322-1.515-.729-2.158-1.814.107-.12.174-.276.174-.45 0-.375-.303-.678-.678-.678s-.678.303-.678.678.303.678.678.678l.221-.04c.416.597 1.09 1.181 1.347 2.828l-.072.091.104.081-.112-.067c-1.157 1.914-.793 4.248.207 5.37-.998 2.546-1.035 4.681-.097 5.868l.002.002.003.003c.119.162.313.233.524.233.189 0 .39-.057.559-.154.312-.179.441-.459.326-.713l-.12.054.119-.056c-.581-1.243-.474-2.713.314-4.37.4.131.778.208 1.145.234l.139.73c.264 1.418.514 2.757 1.297 4.006.132.264.453.387.777.387.122 0 .245-.018.357-.051.385-.116.591-.399.537-.738l-.129.021.125-.042c-.204-.606-.431-1.146-.649-1.67-.373-.894-.725-1.742-.891-2.737.407-.042.797-.129 1.161-.261.825.692 1.661 1.492 2.743 3.406h.001c.072.14.224.215.41.215.105 0 .222-.024.339-.073.365-.155.652-.531.477-1.006v-.001c-.432-1.849-1.426-2.778-2.428-3.547.162-.175.311-.366.442-.576.75.399 1.878 1.005 3.127 2.766l.047.067.011-.008c.151.156.317.24.48.24.096 0 .191-.027.279-.084.306-.194.439-.662.29-1.005zm-8.878-2.493c-.947 0-1.713-.767-1.713-1.713s.767-1.713 1.713-1.713c.947 0 1.713.767 1.713 1.713s-.767 1.713-1.713 1.713zm6.587 4.648l-.084.021v-.001l.084-.02zm-2.007-5.312zm.022 1.006zM11.225 11.604c0 .385-.312.697-.697.697s-.697-.312-.697-.697c0-.385.312-.697.697-.697s.697.312.697.697z"></path></svg>
#  </span>
#  <span class="user-info__nickname user-info__nickname_small">lega</span>
#  </a>
#  <span class="post__time">вчера в 21:04</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513426/">Чем «фрагменты» могут помочь в Веб-разработке на примере Malina.js</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/webdev/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Разработка веб-сайтов'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Разработка веб-сайтов</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/javascript/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'JavaScript'); }" rel="nofollow" title="Вы не подписаны на этот хаб">JavaScript</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><span class="post__type-label" title="Перевод">Перевод</span></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <img src="https://habrastorage.org/webt/fl/zt/fe/flztfetgiamy4r-s5o8lxz0cfaa.png"/><br/>
#  <br/>
#  Никто не спрашивает зачем нужны функции, ведь это очевидная и полезная вешь в программировании. Функции позволяют переиспользовать код и делать архитектуру приложения лучше.<br/>
#  <br/>
#  Почему бы не использовать такую же способность в шаблонах компонентов. В настоящее время многие фреймворки позволяют использовать компоненты внутри других компонентов. Но это больше похоже на подключение модуля, нежели просто функции. Ведь компонент кроме шаблона может иметь свой JavaScript код, свои стили и он весьма изолирован (что хорошо).<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513426/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_91,h_357,f_develop" id="infopanel_post_513426">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_negative" title="Всего голосов 1: ↑0 и ↓1">–1</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513426" data-post-type="publish_ugc_ru,h_91,h_357,f_develop" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
# ...
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">16,1k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513402/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">21</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/SS_2020/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/db1/61b/39d/db161b39db75e0ee7f61a01ec2d4f59d.jpg" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">SS_2020</span>
#  </a>
#  <span class="post__time">вчера в 14:42</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513398/">Есть возраст?</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/health/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Здоровье'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Здоровье</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <div style="text-align:center;"><img alt="image" src="https://habrastorage.org/webt/wq/r5/ia/wqr5iati77ghqppkaqcxo7zmiws.png"/></div><br/>
#  Алоха, хаброжители! Каждый из вас делает это ежедневно. А все вместе мы делаем это всё дольше и дольше. Это — старение. Ожидаемая продолжительность жизни в развитых странах удвоилась за последние 150 лет. <br/>
#  <br/>
#  Этот график в упрощённой форме показывает, что именно мы теряем и приобретаем в течение жизни. Он составлен на основе когортных данных. Из-за того, что данные за определённые периоды были неполными, кривые графика не охватывают все возрастные категории. Например, среди детей были собраны не все данные, либо по абсолютно другим методикам. К тому же детальные исследования среди 80-100-летних стали возможными только недавно — до этого большинство пробандов просто не доживало до таких преклонных лет.<br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513398/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_21996,f_popsci" id="infopanel_post_513398">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 27: ↑25 и ↓2">+23</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513398" data-post-type="publish_ugc_ru,h_21996,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">28</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">7,9k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513398/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">21</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/Andrew-BUSINESS/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/ce6/994/581/ce69945812fa6d9ce92a942d8fb91930.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">Andrew-BUSINESS</span>
#  </a>
#  <span class="post__time">вчера в 14:20</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/post/513396/">Автоматизация бюджетирования: в чем проблема?</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/analysis_design/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Анализ и проектирование систем'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Анализ и проектирование систем</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/erp/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'ERP-системы'); }" rel="nofollow" title="Вы не подписаны на этот хаб">ERP-системы</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/funcprog/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Функциональное программирование'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Функциональное программирование</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/data_warehouse/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Хранилища данных'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Хранилища данных</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/finance/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Финансы в IT'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Финансы в IT</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"><li class="inline-list__item inline-list__item_post-type"><a class="post__type-label" href="https://habr.com/ru/sandbox/" title="Перейти в песочницу">Из песочницы</a></li></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#  <img src="https://habrastorage.org/webt/cw/s3/hv/cws3hvpohftwr9jk8kyshcxw76g.png"/><br/>
#  <br/>
#  Это вводная статья о том, что такое «автоматизация бюджетирования», о каких проблемах говорят, когда используют это словосочетание, и какие IT-инструменты используются в ней.<br/>
#  <br/>
#  Если вы хотите понять, как связаны между собой BI, хранилища данных (DWH), системы автоматизации бюджетирования (Cognos, Anaplan, 1С: Управление холдингом, Бит.Финанс) и чем они отличаются от других корпоративных информационных систем – вам сюда.<br/>
#  <br/>
#  Если вы технический архитектор, который никогда не работал с предметной областью бизнес-планирования – статья тоже для вас.<br/>
#  <br/>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/post/513396/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_ugc_ru,h_397,h_17699,h_17853,h_20116,h_21928,f_develop,f_management,f_admin,f_popsci" id="infopanel_post_513396">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 3: ↑3 и ↓0">+3</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513396" data-post-type="publish_ugc_ru,h_397,h_17699,h_17853,h_20116,h_21928,f_develop,f_management,f_admin,f_popsci" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">10</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,3k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/post/513396/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-count" title="Читать комментарии">3</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>,
#  <article class="post post_preview" lang="ru">
#  <header class="post__meta">
#  <a class="post__user-info user-info" href="https://habr.com/ru/users/1cloud/" title="Автор публикации">
#  <img class="user-info__image-pic user-info__image-pic_small" height="24" src="//habrastorage.org/getpro/habr/avatars/046/cda/7c8/046cda7c89b6fb6154d418fd5cd01a87.png" width="24"/>
#  <span class="user-info__nickname user-info__nickname_small">1cloud</span>
#  </a>
#  <span class="post__time">вчера в 13:54</span>
#  </header>
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/ru/company/1cloud/blog/513354/">Облачный TL;DR: что дает open source, почему разработчики дороже денег и пара слов о личной ИБ</a>
#  </h2>
#  <ul class="post__hubs inline-list">
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/company/1cloud/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Блог компании 1cloud.ru'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Блог компании 1cloud.ru</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/open_source/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Open source'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Open source</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/pm/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Управление проектами'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Управление проектами</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/gtd/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'GTD'); }" rel="nofollow" title="Вы не подписаны на этот хаб">GTD</a>,
#          </li>
#  <li class="inline-list__item inline-list__item_hub">
#  <a class="inline-list__item-link hub-link" href="https://habr.com/ru/hub/remote/" onclick="if (typeof ga === 'function') { ga('send', 'event', 'hub', 'feed page', 'Удалённая работа'); }" rel="nofollow" title="Вы не подписаны на этот хаб">Удалённая работа</a>
#  </li>
#  </ul>
#  <ul class="post__marks inline-list"></ul>
#  <div class="post__body post__body_crop">
#  <div class="post__text post__text-html post__text_v1">
#        Вместо привычных дайджестов <a href="https://1cloud.ru/blog?utm_source=habrahabr&amp;utm_medium=cpm&amp;utm_campaign=tldr&amp;utm_content=blog" rel="nofollow">избранных постов</a> из нашего блога сегодня пробуем новый TL;DR-формат — рассказываем все самое главное из каждого материала. Если захотите детально изучить пруфы и углубиться в какую-либо тему, ссылки на полные версии — в подзаголовках.<br/>
#  <br/>
#  <a href="https://habr.com/ru/company/1cloud/blog/513354/"><img src="https://habrastorage.org/webt/qj/7b/vo/qj7bvoykmmnhmgove4pzqp_b3tg.png"/></a>
#  </div>
#  <a class="btn btn_x-large btn_outline_blue post__habracut-btn" href="https://habr.com/ru/company/1cloud/blog/513354/#habracut">Читать дальше →</a>
#  </div>
#  <footer class="post__footer">
#  <ul class="post-stats js-user_" data-post-type="publish_corp_ru,c_1cloud,h_144,h_20682,h_20690,h_22470,f_develop,f_management" id="infopanel_post_513354">
#  <li class="post-stats__item">
#  <div class="post-stats__result">
#  <span class="post-stats__result-icon">
#  <svg class="icon-svg_votes" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#counter-rating"></use></svg>
#  </span>
#  <span class="post-stats__result-counter voting-wjt__counter_positive" title="Всего голосов 10: ↑8 и ↓2">+6</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_bookmark">
#  <button class="btn bookmark-btn bookmark-btn_post" data-action="add" data-id="513354" data-post-type="publish_corp_ru,c_1cloud,h_144,h_20682,h_20690,h_22470,f_develop,f_management" data-type="2" disabled="" onclick="posts_add_to_favorite(this);" title="Только зарегистрированные пользователи могут добавлять публикации в закладки" type="button">
#  <span class="btn_inner"><svg class="icon-svg_bookmark" height="16" width="10"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#book"></use></svg><span class="bookmark__counter js-favs_count" title="Количество пользователей, добавивших публикацию в закладки">19</span></span>
#  </button>
#  </li>
#  <li class="post-stats__item post-stats__item_views">
#  <div class="post-stats__views" title="Количество просмотров">
#  <svg class="icon-svg_views-count" height="12" width="21"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#eye"></use></svg><span class="post-stats__views-count">1,4k</span>
#  </div>
#  </li>
#  <li class="post-stats__item post-stats__item_comments">
#  <a class="post-stats__comments-link" href="https://habr.com/ru/company/1cloud/blog/513354/#comments" rel="nofollow">
#  <svg class="icon-svg_post-comments" height="16" width="16"><use xlink:href="https://habr.com/5f243638/images/common-svg-sprite.svg#comment"></use></svg><span class="post-stats__comments-text" title="Добавить комментарий">Комментировать</span>
#  </a>
#  </li>
#  </ul>
#  </footer>
#  </article>]

# %%
list_ = []

for post in posts:
    post_id = post.parent.attrs.get('id')
   # если идентификатор не найден, это что-то странное, пропускаем
    if not post_id:
        continue
    post_id = int(post_id.split('_')[-1])
    hubs = post.find_all('a', class_='hub-link') #выделение тегов к статьям
    
    for hub in hubs:
            hub_lower = hub.text.lower()
            # ищем вхождение хотя бы одного желаемого хаба
            if any([hub_lower in words for words in KEYWORDS]):
                # пост нам интересен - делаем с ним все что захотим: можно отправит в телеграм уведомление, можно на почту и т.п.
                title_element = post.find('a', class_='post__title_link')
                a = title_element.attrs.get('href')
                soup = BeautifulSoup(requests.get(a).text, 'html.parser')
                time.sleep(0.3)
                text = soup.find('div', class_='post__text post__text-html post__text_v1').text
                title_element2 = post.find('a', class_='post__title_link').text
                date = post.find('span', class_='post__time').text
                row = {'date': date, 'title': title_element2, 'ссылка': a, 'text': text}
                list_.append(row)
                # так как пост уже нам подошел - дальше нет смысла проверять хабы
                break

# %%
df = pd.DataFrame(list_)
df
# Out:
#             date                                              title  \
# 0  вчера в 18:03  HackTheBox. Прохождение Oouch. OAuth2, RCE в u...
# 1  вчера в 15:43  Небольшое расследование расследования по делу ...
# 2  вчера в 14:20      Автоматизация бюджетирования: в чем проблема?
# 3  вчера в 13:54  Облачный TL;DR: что дает open source, почему р...
#
#                                             ссылка  \
# 0                 https://habr.com/ru/post/513378/
# 1                 https://habr.com/ru/post/513402/
# 2                 https://habr.com/ru/post/513396/
# 3  https://habr.com/ru/company/1cloud/blog/513354/
#
#                                                 text
# 0  \r\nПродолжаю публикацию решений отправленных ...
# 1  Наверное, все помнят, как около 2 недель назад...
# 2  \n\r\nЭто вводная статья о том, что такое «авт...
# 3  Вместо привычных дайджестов избранных постов и...

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Улучшить скрипт так, чтобы он анализировал не только preview-информацию статьи, но и весь текст статьи целиком.
#
# Для этого потребуется получать страницы статей и искать по тексту внутри этой страницы.
#
# Итоговый датафрейм формировать со столбцами: <дата> - <заголовок> - <ссылка> - <текст статьи>

# %% [markdown]
# ## Задание 2.

# %% [markdown]
# ### Обязательная часть

# %% [markdown]
# Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса [Avast Hack Ckeck](https://www.avast.com/hackcheck/).
# Список email-ов задаем переменной в начале кода:
# `EMAIL = [xxx@x.ru, yyy@y.com]`
#
# В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>.

# %%
URL2 = 'https://digibody.avast.com/v1/web/leaks'
params = {'email': "xxx@x.ru"}
#URL2 = 'https://www.avast.com'
#URL2 = 'https://digibody.avast.com/v1/web/leaks'

# %%
res = requests.post(URL2, json=params)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"status":"ok","value":[{"leak_id":"037a277e-d484-4c34-8473-904024e489e1","username":"xxx@x.ru","domain":"","passwords":[{"password":null,"encrypted":false}],"leak_info":{"id":"037a277e-d484-4c34-8473-904024e489e1","date":1513900800000,"title":"Combolist of 1.4 Billion Credentials","description":"The proliferation of stolen or leaked databases has given rise to credential stuffing, a fairly simple technique in which criminals load lists of stolen credentials, called combo lists, into automated brute-forcing tools to test credentials en masse. These tools test stolen passwords against thousands of targeted websites and applications until there is a match.\\n\\nThis particular combo list was likely compiled over time from a variety of public and private breaches. It contains approximately 1.4 billion email and password records. Criminals are actively leveraging this list, along with credential stuffing tools, to gain unauthorized access to targeted websites. This list has been made public on a number of hacking forums and paste sites.","number_of_entries":1335491701,"source_references":[],"media_references":[],"domains":[""],"picture_url":null,"service_name":null},"marked_resolved":false,"leak_date":1513900800000,"passwords_count":1},{"leak_id":"cf7afbbb-7695-4f97-b755-3d63df87828f","username":"xxx@x.ru","domain":"","passwords":[{"password":null,"encrypted":false}],"leak_info":{"id":"cf7afbbb-7695-4f97-b755-3d63df87828f","date":1549411200000,"title":"Collection #4 Combo List","description":"On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \\r\\n\\r\\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\\r\\n\\r\\nCollection #4 consists of more than 1 billion unique records across 12,368 individual files.","number_of_entries":1834706170,"source_references":[],"media_references":[],"domains":[""],"picture_url":null,"service_name":null},"marked_resolved":false,"leak_date":1549411200000,"passwords_count":1},{"leak_id":"ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3","username":"aleksey1688","domain":"cdprojektred.com","passwords":[{"password":null,"encrypted":true}],"leak_info":{"id":"ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3","date":1485820800000,"title":"CD Projekt Red","description":"In March 2016, CDProjektRed.com.com\'s forum database was breached. The attacker may have exploited a vulnerability in vBulletin. The stolen data contains over 1,870,000 user records including associated usernames, email addresses, hashed passwords, and salts. The leaked credentials are being shared and sold privately on the dark web.","number_of_entries":1871459,"source_references":[],"media_references":[],"domains":["cdprojektred.com"],"picture_url":null,"service_name":null},"marked_resolved":false,"leak_date":1485820800000,"passwords_count":1},{"leak_id":"053fe29c-422d-4b69-bce2-1ce4904af697","username":"xixixixixixixixixixi","domain":"mail.ru","passwords":[{"password":null,"encrypted":false}],"leak_info":{"id":"053fe29c-422d-4b69-bce2-1ce4904af697","date":1487030400000,"title":"Parapa","description":"In July and August 2016, two criminals executed attacks against three separate forums hosted by Mail.ru including the Russian forum Parapa. Shortly after the breach occurred, the contents of Parapa\'s database were leaked publicly. The database contains usernames, email addresses, and hashed passwords for around 5 million users.","number_of_entries":5029003,"source_references":[],"media_references":[],"domains":["mail.ru"],"picture_url":"https://pamcdn.ava ...

# %%
import json

# %%
vocab = json.loads(res.text)
vocab
# Out:
# {'status': 'ok',
#  'value': [{'leak_id': '037a277e-d484-4c34-8473-904024e489e1',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': '037a277e-d484-4c34-8473-904024e489e1',
#     'date': 1513900800000,
#     'title': 'Combolist of 1.4 Billion Credentials',
#     'description': 'The proliferation of stolen or leaked databases has given rise to credential stuffing, a fairly simple technique in which criminals load lists of stolen credentials, called combo lists, into automated brute-forcing tools to test credentials en masse. These tools test stolen passwords against thousands of targeted websites and applications until there is a match.\n\nThis particular combo list was likely compiled over time from a variety of public and private breaches. It contains approximately 1.4 billion email and password records. Criminals are actively leveraging this list, along with credential stuffing tools, to gain unauthorized access to targeted websites. This list has been made public on a number of hacking forums and paste sites.',
#     'number_of_entries': 1335491701,
#     'source_references': [],
#     'media_references': [],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1513900800000,
#    'passwords_count': 1},
#   {'leak_id': 'cf7afbbb-7695-4f97-b755-3d63df87828f',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': 'cf7afbbb-7695-4f97-b755-3d63df87828f',
#     'date': 1549411200000,
#     'title': 'Collection #4 Combo List',
#     'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #4 consists of more than 1 billion unique records across 12,368 individual files.',
#     'number_of_entries': 1834706170,
#     'source_references': [],
#     'media_references': [],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1549411200000,
#    'passwords_count': 1},
#   {'leak_id': 'ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3',
#    'username': 'aleksey1688',
#    'domain': 'cdprojektred.com',
#    'passwords': [{'password': None, 'encrypted': True}],
#    'leak_info': {'id': 'ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3',
#     'date': 1485820800000,
#     'title': 'CD Projekt Red',
#     'description': "In March 2016, CDProjektRed.com.com's forum database was breached. The attacker may have exploited a vulnerability in vBulletin. The stolen data contains over 1,870,000 user records including associated usernames, email addresses, hashed passwords, and salts. The leaked credentials are being shared and sold privately on the dark web.",
#     'number_of_entries': 1871459,
#     'source_references': [],
#     'media_references': [],
#     'domains': ['cdprojektred.com'],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1485820800000,
#    'passwords_count': 1},
#   {'leak_id': '053fe29c-422d-4b69-bce2-1ce4904af697',
#    'username': 'xixixixixixixixixixi',
#    'domain': 'mail.ru',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': '053fe29c-422d-4b69-bce2-1ce4904af697',
#     'date': 1487030400000,
#     'title': 'Parapa',
#     'description': "In July and August 2016, two criminals executed attacks against three separate forums hosted by Mail.ru including the Russian forum Parapa. Shortly after the breach occurred, the contents of Parapa's database were leaked publicly. The database contains usernames, email addresses, and hashed passwords for around 5 million users.",
#     'number_of_entries': 5029003,
#     'source_references': [],
#     'media_references': [],
#     'domains': ['mail.ru'],
#     'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/mail_ru.png',
#     'service_name': 'Mail.Ru'},
#    'marked_resolved': False,
#    'leak_date': 1487030400000,
#    'passwords_count': 1},
#   {'leak_id': '7f6e3b64-9951-458f-b565-8ff02baf1a59',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': True}],
#    'leak_info': {'id': '7f6e3b64-9951-458f-b565-8ff02baf1a59',
#     'date': 1488931200000,
#     'title': 'Sensitive Source',
#     'description': "This source has been marked as sensitive due to one of the following reasons:Revealing the source may compromise an on-going investigationThe affected site is of a controversial nature but does not validate email addresses and could therefore be used to tarnish an employee's reputation",
#     'number_of_entries': 39246714,
#     'source_references': [],
#     'media_references': [],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1488931200000,
#    'passwords_count': 1},
#   {'leak_id': '71db3f29-006d-4158-a3f0-8102652fbf57',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': '71db3f29-006d-4158-a3f0-8102652fbf57',
#     'date': 1549411200000,
#     'title': 'Collection #5 Combo List',
#     'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #5 consists of more than 540 million unique records across 16,022 individual files.',
#     'number_of_entries': 540904910,
#     'source_references': [],
#     'media_references': [],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1549411200000,
#    'passwords_count': 1},
#   {'leak_id': '83571809-585b-4fff-a72f-cdf0bc345916',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': '83571809-585b-4fff-a72f-cdf0bc345916',
#     'date': 1549411200000,
#     'title': '2019 Antipublic Combo List',
#     'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nThe "Antipublic #1" collection consists of more than 1.7 billion unique records across 303 individual files.',
#     'number_of_entries': 1737098076,
#     'source_references': [],
#     'media_references': [],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1549411200000,
#    'passwords_count': 1},
#   {'leak_id': '2702007e-b243-4836-b1d6-a2d85f03b469',
#    'username': 'stalkera116',
#    'domain': 'mail.ru',
#    'passwords': [{'password': None, 'encrypted': True}],
#    'leak_info': {'id': '2702007e-b243-4836-b1d6-a2d85f03b469',
#     'date': 1487030400000,
#     'title': 'CFire Mail',
#     'description': "In July and August of 2016, two criminals carried out attacks on three separate forums hosted by Mail.ru, including CFire. The hackers used known SQL injection vulnerabilities found in older vBulletin forum software to obtain access to the databases. Shortly after the breach itself, the contents of CFire's database were leaked publicly. The database contains usernames, email addresses, and MD5 hashed passwords for just under 13 million users.",
#     'number_of_entries': 12880232,
#     'source_references': [],
#     'media_references': [],
#     'domains': ['mail.ru'],
#     'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/mail_ru.png',
#     'service_name': 'Mail.Ru'},
#    'marked_resolved': False,
#    'leak_date': 1487030400000,
#    'passwords_count': 1},
#   {'leak_id': '7f667060-f7c1-4f48-b93d-ecb4d066ba4b',
#    'username': 'xxx@x.ru',
#    'domain': 'adobe.com',
#    'passwords': [{'password': None, 'encrypted': True}],
#    'leak_info': {'id': '7f667060-f7c1-4f48-b93d-ecb4d066ba4b',
#     'date': 1477008000000,
#     'title': 'Adobe Systems',
#     'description': "In October of 2013, criminals penetrated Adobe's corporate network and the stole source code for several of its software products. The affected products included Adobe's ColdFusion web application platform as well as the Acrobat suite of products. Adobe asserts that criminals also accessed nearly three-million customer credit card records and stole login data for an undisclosed number of Adobe user accounts.",
#     'number_of_entries': 152046506,
#     'source_references': [],
#     'media_references': ['http://www.theverge.com/2013/11/7/5078560/over-150-million-breached-records-from-adobe-hack-surface-online',
#      'http://www.cnet.com/news/adobe-hack-attack-affected-38-million-accounts/'],
#     'domains': ['adobe.com'],
#     'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/adobe_com.png',
#     'service_name': 'Adobe'},
#    'marked_resolved': False,
#    'leak_date': 1477008000000,
#    'passwords_count': 1},
#   {'leak_id': 'b15edc13-85b2-4c53-a54a-fee2d6b861ea',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': 'b15edc13-85b2-4c53-a54a-fee2d6b861ea',
#     'date': 1548720000000,
#     'title': 'Collection #2 Combo List',
#     'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #2 consists of more than 3 billion unique records across 24,921 individual files.',
#     'number_of_entries': 3039625486,
#     'source_references': [],
#     'media_references': [],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1548720000000,
#    'passwords_count': 1},
#   {'leak_id': '056d9871-b968-459a-8742-daa5aae7932f',
#    'username': 'xxx@x.ru',
#    'domain': 'vk.com',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': '056d9871-b968-459a-8742-daa5aae7932f',
#     'date': 1477699200000,
#     'title': 'VK',
#     'description': "Popular Russian social networking platform VKontakte was breached in late 2012. Over 100 million clear-text passwords were compromised in the breach. Breached credential sets included victims' e-mail addresses, passwords, dates of birth, phone numbers and location details. The credential set was advertised on a dark web marketplace as of June 2016 for a price of one bitcoin. ",
#     'number_of_entries': 91262655,
#     'source_references': [],
#     'media_references': ['http://motherboard.vice.com/read/another-day-another-hack-100-million-accounts-for-vk-russias-facebook',
#      'http://www.zdnet.com/article/vkontakte-vk-hacked-171-million-accounts-sold-dark-web/'],
#     'domains': ['vk.com'],
#     'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/vk_com.png',
#     'service_name': 'VK'},
#    'marked_resolved': False,
#    'leak_date': 1477699200000,
#    'passwords_count': 1},
#   {'leak_id': 'b027f485-3922-433c-8448-56fd1b2f308a',
#    'username': 'xxx@x.ru',
#    'domain': '',
#    'passwords': [{'password': None, 'encrypted': False}],
#    'leak_info': {'id': 'b027f485-3922-433c-8448-56fd1b2f308a',
#     'date': 1548374400000,
#     'title': 'Collection #1 Combo List',
#     'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #1 consists of more than 1 billion unique records across 12,368 individual files.',
#     'number_of_entries': 1012769430,
#     'source_references': [],
#     'media_references': ['https://www.wired.com/story/collection-one-breach-email-accounts-passwords/'],
#     'domains': [''],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1548374400000,
#    'passwords_count': 1},
#   {'leak_id': '8c9faf25-41e0-431c-8090-93950692cc61',
#    'username': 'xcbear',
#    'domain': 'imesh.com',
#    'passwords': [{'password': None, 'encrypted': True}],
#    'leak_info': {'id': '8c9faf25-41e0-431c-8090-93950692cc61',
#     'date': 1477180800000,
#     'title': 'iMesh',
#     'description': 'In June 2016, a cache of over 51 million user credentials from the online sharing service iMesh appeared for sale on a dark web marketplace.  The database contained user email addresses, usernames, passwords, IP addresses and location.',
#     'number_of_entries': 50913222,
#     'source_references': [],
#     'media_references': ['https://www.zdnet.com/article/51-million-imesh-file-sharing-accounts-for-sale-dark-web/'],
#     'domains': ['imesh.com'],
#     'picture_url': None,
#     'service_name': None},
#    'marked_resolved': False,
#    'leak_date': 1477180800000,
#    'passwords_count': 1}]}

# %%
type(vocab)
vocab2 = vocab['value']
vocab2
# Out:
# [{'leak_id': '037a277e-d484-4c34-8473-904024e489e1',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': '037a277e-d484-4c34-8473-904024e489e1',
#    'date': 1513900800000,
#    'title': 'Combolist of 1.4 Billion Credentials',
#    'description': 'The proliferation of stolen or leaked databases has given rise to credential stuffing, a fairly simple technique in which criminals load lists of stolen credentials, called combo lists, into automated brute-forcing tools to test credentials en masse. These tools test stolen passwords against thousands of targeted websites and applications until there is a match.\n\nThis particular combo list was likely compiled over time from a variety of public and private breaches. It contains approximately 1.4 billion email and password records. Criminals are actively leveraging this list, along with credential stuffing tools, to gain unauthorized access to targeted websites. This list has been made public on a number of hacking forums and paste sites.',
#    'number_of_entries': 1335491701,
#    'source_references': [],
#    'media_references': [],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1513900800000,
#   'passwords_count': 1},
#  {'leak_id': 'cf7afbbb-7695-4f97-b755-3d63df87828f',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': 'cf7afbbb-7695-4f97-b755-3d63df87828f',
#    'date': 1549411200000,
#    'title': 'Collection #4 Combo List',
#    'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #4 consists of more than 1 billion unique records across 12,368 individual files.',
#    'number_of_entries': 1834706170,
#    'source_references': [],
#    'media_references': [],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1549411200000,
#   'passwords_count': 1},
#  {'leak_id': 'ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3',
#   'username': 'aleksey1688',
#   'domain': 'cdprojektred.com',
#   'passwords': [{'password': None, 'encrypted': True}],
#   'leak_info': {'id': 'ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3',
#    'date': 1485820800000,
#    'title': 'CD Projekt Red',
#    'description': "In March 2016, CDProjektRed.com.com's forum database was breached. The attacker may have exploited a vulnerability in vBulletin. The stolen data contains over 1,870,000 user records including associated usernames, email addresses, hashed passwords, and salts. The leaked credentials are being shared and sold privately on the dark web.",
#    'number_of_entries': 1871459,
#    'source_references': [],
#    'media_references': [],
#    'domains': ['cdprojektred.com'],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1485820800000,
#   'passwords_count': 1},
#  {'leak_id': '053fe29c-422d-4b69-bce2-1ce4904af697',
#   'username': 'xixixixixixixixixixi',
#   'domain': 'mail.ru',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': '053fe29c-422d-4b69-bce2-1ce4904af697',
#    'date': 1487030400000,
#    'title': 'Parapa',
#    'description': "In July and August 2016, two criminals executed attacks against three separate forums hosted by Mail.ru including the Russian forum Parapa. Shortly after the breach occurred, the contents of Parapa's database were leaked publicly. The database contains usernames, email addresses, and hashed passwords for around 5 million users.",
#    'number_of_entries': 5029003,
#    'source_references': [],
#    'media_references': [],
#    'domains': ['mail.ru'],
#    'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/mail_ru.png',
#    'service_name': 'Mail.Ru'},
#   'marked_resolved': False,
#   'leak_date': 1487030400000,
#   'passwords_count': 1},
#  {'leak_id': '7f6e3b64-9951-458f-b565-8ff02baf1a59',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': True}],
#   'leak_info': {'id': '7f6e3b64-9951-458f-b565-8ff02baf1a59',
#    'date': 1488931200000,
#    'title': 'Sensitive Source',
#    'description': "This source has been marked as sensitive due to one of the following reasons:Revealing the source may compromise an on-going investigationThe affected site is of a controversial nature but does not validate email addresses and could therefore be used to tarnish an employee's reputation",
#    'number_of_entries': 39246714,
#    'source_references': [],
#    'media_references': [],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1488931200000,
#   'passwords_count': 1},
#  {'leak_id': '71db3f29-006d-4158-a3f0-8102652fbf57',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': '71db3f29-006d-4158-a3f0-8102652fbf57',
#    'date': 1549411200000,
#    'title': 'Collection #5 Combo List',
#    'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #5 consists of more than 540 million unique records across 16,022 individual files.',
#    'number_of_entries': 540904910,
#    'source_references': [],
#    'media_references': [],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1549411200000,
#   'passwords_count': 1},
#  {'leak_id': '83571809-585b-4fff-a72f-cdf0bc345916',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': '83571809-585b-4fff-a72f-cdf0bc345916',
#    'date': 1549411200000,
#    'title': '2019 Antipublic Combo List',
#    'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nThe "Antipublic #1" collection consists of more than 1.7 billion unique records across 303 individual files.',
#    'number_of_entries': 1737098076,
#    'source_references': [],
#    'media_references': [],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1549411200000,
#   'passwords_count': 1},
#  {'leak_id': '2702007e-b243-4836-b1d6-a2d85f03b469',
#   'username': 'stalkera116',
#   'domain': 'mail.ru',
#   'passwords': [{'password': None, 'encrypted': True}],
#   'leak_info': {'id': '2702007e-b243-4836-b1d6-a2d85f03b469',
#    'date': 1487030400000,
#    'title': 'CFire Mail',
#    'description': "In July and August of 2016, two criminals carried out attacks on three separate forums hosted by Mail.ru, including CFire. The hackers used known SQL injection vulnerabilities found in older vBulletin forum software to obtain access to the databases. Shortly after the breach itself, the contents of CFire's database were leaked publicly. The database contains usernames, email addresses, and MD5 hashed passwords for just under 13 million users.",
#    'number_of_entries': 12880232,
#    'source_references': [],
#    'media_references': [],
#    'domains': ['mail.ru'],
#    'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/mail_ru.png',
#    'service_name': 'Mail.Ru'},
#   'marked_resolved': False,
#   'leak_date': 1487030400000,
#   'passwords_count': 1},
#  {'leak_id': '7f667060-f7c1-4f48-b93d-ecb4d066ba4b',
#   'username': 'xxx@x.ru',
#   'domain': 'adobe.com',
#   'passwords': [{'password': None, 'encrypted': True}],
#   'leak_info': {'id': '7f667060-f7c1-4f48-b93d-ecb4d066ba4b',
#    'date': 1477008000000,
#    'title': 'Adobe Systems',
#    'description': "In October of 2013, criminals penetrated Adobe's corporate network and the stole source code for several of its software products. The affected products included Adobe's ColdFusion web application platform as well as the Acrobat suite of products. Adobe asserts that criminals also accessed nearly three-million customer credit card records and stole login data for an undisclosed number of Adobe user accounts.",
#    'number_of_entries': 152046506,
#    'source_references': [],
#    'media_references': ['http://www.theverge.com/2013/11/7/5078560/over-150-million-breached-records-from-adobe-hack-surface-online',
#     'http://www.cnet.com/news/adobe-hack-attack-affected-38-million-accounts/'],
#    'domains': ['adobe.com'],
#    'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/adobe_com.png',
#    'service_name': 'Adobe'},
#   'marked_resolved': False,
#   'leak_date': 1477008000000,
#   'passwords_count': 1},
#  {'leak_id': 'b15edc13-85b2-4c53-a54a-fee2d6b861ea',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': 'b15edc13-85b2-4c53-a54a-fee2d6b861ea',
#    'date': 1548720000000,
#    'title': 'Collection #2 Combo List',
#    'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #2 consists of more than 3 billion unique records across 24,921 individual files.',
#    'number_of_entries': 3039625486,
#    'source_references': [],
#    'media_references': [],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1548720000000,
#   'passwords_count': 1},
#  {'leak_id': '056d9871-b968-459a-8742-daa5aae7932f',
#   'username': 'xxx@x.ru',
#   'domain': 'vk.com',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': '056d9871-b968-459a-8742-daa5aae7932f',
#    'date': 1477699200000,
#    'title': 'VK',
#    'description': "Popular Russian social networking platform VKontakte was breached in late 2012. Over 100 million clear-text passwords were compromised in the breach. Breached credential sets included victims' e-mail addresses, passwords, dates of birth, phone numbers and location details. The credential set was advertised on a dark web marketplace as of June 2016 for a price of one bitcoin. ",
#    'number_of_entries': 91262655,
#    'source_references': [],
#    'media_references': ['http://motherboard.vice.com/read/another-day-another-hack-100-million-accounts-for-vk-russias-facebook',
#     'http://www.zdnet.com/article/vkontakte-vk-hacked-171-million-accounts-sold-dark-web/'],
#    'domains': ['vk.com'],
#    'picture_url': 'https://pamcdn.avast.com/pamcdn/icons/vk_com.png',
#    'service_name': 'VK'},
#   'marked_resolved': False,
#   'leak_date': 1477699200000,
#   'passwords_count': 1},
#  {'leak_id': 'b027f485-3922-433c-8448-56fd1b2f308a',
#   'username': 'xxx@x.ru',
#   'domain': '',
#   'passwords': [{'password': None, 'encrypted': False}],
#   'leak_info': {'id': 'b027f485-3922-433c-8448-56fd1b2f308a',
#    'date': 1548374400000,
#    'title': 'Collection #1 Combo List',
#    'description': 'On January 7, 2019, an online user named Sanixer advertised 5 massive collections of leaked email and password combinations for sale on a popular hacking forum.   These collections include a total of 993GB of personal information and seem to be mostly rehashes of previous breaches.  The sheer size of so much breach data available in one place captured a lot of attention in the mainstream media.  \r\n\r\nThe collections were hosted for a short time on the popular hosting service MEGA, and have since been shared via download torrents and private links hundreds of times.  Lifetime access to the data was being sold for $45.\r\n\r\nCollection #1 consists of more than 1 billion unique records across 12,368 individual files.',
#    'number_of_entries': 1012769430,
#    'source_references': [],
#    'media_references': ['https://www.wired.com/story/collection-one-breach-email-accounts-passwords/'],
#    'domains': [''],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1548374400000,
#   'passwords_count': 1},
#  {'leak_id': '8c9faf25-41e0-431c-8090-93950692cc61',
#   'username': 'xcbear',
#   'domain': 'imesh.com',
#   'passwords': [{'password': None, 'encrypted': True}],
#   'leak_info': {'id': '8c9faf25-41e0-431c-8090-93950692cc61',
#    'date': 1477180800000,
#    'title': 'iMesh',
#    'description': 'In June 2016, a cache of over 51 million user credentials from the online sharing service iMesh appeared for sale on a dark web marketplace.  The database contained user email addresses, usernames, passwords, IP addresses and location.',
#    'number_of_entries': 50913222,
#    'source_references': [],
#    'media_references': ['https://www.zdnet.com/article/51-million-imesh-file-sharing-accounts-for-sale-dark-web/'],
#    'domains': ['imesh.com'],
#    'picture_url': None,
#    'service_name': None},
#   'marked_resolved': False,
#   'leak_date': 1477180800000,
#   'passwords_count': 1}]

# %%
type(vocab2)
# Out:
# list

# %%
df3 = pd.DataFrame(vocab2)
df3[['username', 'leak_date', 'leak_info']]
# Out:
#                 username      leak_date  \
# 0               xxx@x.ru  1513900800000
# 1               xxx@x.ru  1549411200000
# 2            aleksey1688  1485820800000
# 3   xixixixixixixixixixi  1487030400000
# 4               xxx@x.ru  1488931200000
# 5               xxx@x.ru  1549411200000
# 6               xxx@x.ru  1549411200000
# 7            stalkera116  1487030400000
# 8               xxx@x.ru  1477008000000
# 9               xxx@x.ru  1548720000000
# 10              xxx@x.ru  1477699200000
# 11              xxx@x.ru  1548374400000
# 12                xcbear  1477180800000
#
#                                             leak_info
# 0   {'id': '037a277e-d484-4c34-8473-904024e489e1',...
# 1   {'id': 'cf7afbbb-7695-4f97-b755-3d63df87828f',...
# 2   {'id': 'ee4ffcf9-e69f-49b7-9c61-70f94fa82ad3',...
# 3   {'id': '053fe29c-422d-4b69-bce2-1ce4904af697',...
# 4   {'id': '7f6e3b64-9951-458f-b565-8ff02baf1a59',...
# 5   {'id': '71db3f29-006d-4158-a3f0-8102652fbf57',...
# 6   {'id': '83571809-585b-4fff-a72f-cdf0bc345916',...
# 7   {'id': '2702007e-b243-4836-b1d6-a2d85f03b469',...
# 8   {'id': '7f667060-f7c1-4f48-b93d-ecb4d066ba4b',...
# 9   {'id': 'b15edc13-85b2-4c53-a54a-fee2d6b861ea',...
# 10  {'id': '056d9871-b968-459a-8742-daa5aae7932f',...
# 11  {'id': 'b027f485-3922-433c-8448-56fd1b2f308a',...
# 12  {'id': '8c9faf25-41e0-431c-8090-93950692cc61',...

# %%
z = {}
for el in vocab2:
    el
z = el
z
# Out:
# {'leak_id': '8c9faf25-41e0-431c-8090-93950692cc61',
#  'username': 'xcbear',
#  'domain': 'imesh.com',
#  'passwords': [{'password': None, 'encrypted': True}],
#  'leak_info': {'id': '8c9faf25-41e0-431c-8090-93950692cc61',
#   'date': 1477180800000,
#   'title': 'iMesh',
#   'description': 'In June 2016, a cache of over 51 million user credentials from the online sharing service iMesh appeared for sale on a dark web marketplace.  The database contained user email addresses, usernames, passwords, IP addresses and location.',
#   'number_of_entries': 50913222,
#   'source_references': [],
#   'media_references': ['https://www.zdnet.com/article/51-million-imesh-file-sharing-accounts-for-sale-dark-web/'],
#   'domains': ['imesh.com'],
#   'picture_url': None,
#   'service_name': None},
#  'marked_resolved': False,
#  'leak_date': 1477180800000,
#  'passwords_count': 1}

# %%
df4 = pd.DataFrame(z)
df4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8a73048fa8a9> in <module>
# ----> 1 df4 = pd.DataFrame(z)
#       2 df4
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     367             if have_dicts:
#     368                 raise ValueError(
# --> 369                     "Mixing dicts with non-Series may lead to ambiguous ordering."
#     370                 )
#     371
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %% [markdown]
# ### Дополнительная часть (необязательная)

# %% [markdown]
# Написать скрипт, который будет получать 50 последних постов указанной группы во Вконтакте.
# Документация к API VK: https://vk.com/dev/methods
# , вам поможет метод [wall.get](https://vk.com/dev/wall.get)```
# GROUP = 'netology'
# TOKEN = УДАЛЯЙТЕ В ВЕРСИИ ДЛЯ ПРОВЕРКИ, НА GITHUB НЕ ВЫКЛАДЫВАТЬ
# ```
#
# В итоге должен формироваться датафрейм со столбцами: <дата поста> - <текст поста>.

# %% [markdown]
# #### ПРИМЕЧАНИЕ
# Домашнее задание сдается ссылкой на репозиторий [GitHub](https://github.com/).
# Не сможем проверить или помочь, если вы пришлете:
# - файлы;
# - архивы;
# - скриншоты кода.
#
# Все обсуждения и консультации по выполнению домашнего задания ведутся только на соответствующем канале в slack.
#
# ##### Как правильно задавать вопросы аспирантам, преподавателям и коллегам?
# Прежде чем задать вопрос необходимо попробовать найти ответ самому в интернете. Навык самостоятельного поиска информации – один из важнейших, и каждый практикующий специалист любого уровня это делает каждый день.
#
# Любой вопрос должен быть сформулирован по алгоритму:
# 1) Что я делаю?
# 2) Какого результата я ожидаю?
# 3) Как фактический результат отличается от ожидаемого?
# 4) Что я уже попробовал сделать, чтобы исправить проблему?
#
# По возможности, прикрепляйте к вопросу скриншоты, либо ссылки на код. Оставляйте только проблемный и воспроизводимый участок кода, все решение выкладывать не допускается.
